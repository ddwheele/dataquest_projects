# %% [markdown]
# # Visualizing Earnings Based on College Majors
#
# This project uses [data](https://github.com/fivethirtyeight/data/tree/master/college-majors) published by FiveThirtyEight. It was collected by American Community Survey.
#
# First let's look at the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

recent_grads = pd.read_csv('recent-grads.csv')
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
recent_grads.size
# Out:
# 3633

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  ...  \
# 168    Biology & Life Science    0.637293           47      6259  ...
# 169  Psychology & Social Work    0.817099            7      2125  ...
# 170  Psychology & Social Work    0.799859           13      2101  ...
# 171  Psychology & Social Work    0.798746           21      3777  ...
# 172                 Education    0.877960            2       742  ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape[0]

# %%
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]
print(cleaned_data_count)
# Out:
# 172

# %% [markdown]
# This is still too many majors to draw meaningful data from. Suppose we limited it to the most popular majors, I wonder if we would see stronger trends.

# %%
popular = recent_grads[recent_grads['Sample_size'] > 250]
print(popular.shape[0])
# Out:
# 54

# %%
# Popularity of Major vs. Median Earnings
recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
popular.plot(x='Sample_size', y='Median', kind='scatter')

# Unpopular majors can earn lots of money, or not, or anything in between.

# %%
# Popularity of Major vs. Unemployment Rate
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
popular.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')

# Unpopular majors can have any number of unemployed. The more unpopular, the greater the variation.

# %%
# Graduates Employed Full Time vs. Median Earnings
recent_grads.plot(x='Full_time', y='Median', kind='scatter')
popular.plot(x='Full_time', y='Median', kind='scatter')

# Again, the fewer people employed, the greater the variation in earnings.
# Data do seem to indicate that very popular fields will earn less money.

# %%
# Percent Women vs. Unemployment Rate
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')
popular.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')

# The percent of women seems unrelated to the unemployment rate

# %%
# Number of Men vs. Median Earnings
recent_grads.plot(x='Men', y='Median', kind='scatter')
popular.plot(x='Men', y='Median', kind='scatter')

# Once again, the fewer the numbers the higher the variation.
# It does look like if there are lots of men, earnings are lower.

# %%
# Number of Women vs. Median Earnings
recent_grads.plot(x='Women', y='Median', kind='scatter')
popular.plot(x='Women', y='Median', kind='scatter')

# If lots of women, earnings are lower.

# %% [markdown]
# Hmm, looking at the data, it seems that restricting to popular majors did not bring out any significant trends.

# %% [markdown]
# # Histograms

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize=(5,12))
for r in range(4,8):
    ax = fig.add_subplot(4,1,r-3)
    ax = recent_grads[cols[r]].plot(kind='hist', rot=40)

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,700))

# %%
recent_grads['Median'].hist(bins=25,range=(0,80000))
# The most common median salary is ~$33K.

# %%
recent_grads['Employed'].hist(bins=25,range=(0,200000))

# %%
recent_grads['Full_time'].hist(bins=25,range=(0,200000))

# %%
recent_grads['ShareWomen'].hist(bins=25)

# %%
recent_grads['Unemployment_rate'].hist(bins=25)

# %%
recent_grads['Men'].hist(bins=25,range=(0,100000))

# %%
recent_grads['Women'].hist(bins=25,range=(0,100000))

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11bb425f8>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median','Unemployment_rate']], figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11bcbfc18>,
# ...
#       dtype=object)

# %%
recent_grads.sort_values('ShareWomen', inplace=True)

recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen', legend=False)

# Majors that have the least and the most women
# The labels get messed up if I try to rotate them

# %%
recent_grads.sort_values('Median', inplace=True)

recent_grads[:10].plot.bar(x='Major', y='Median', legend=False)
recent_grads[-10:].plot.bar(x='Major', y='Median', legend=False)

# Hmm, some of these least- and most-lucrative majors look familiar from the last plot
# I wonder ...

# %%
# Percent Women vs. Median Earnings
recent_grads.plot(x='ShareWomen', y='Median', kind='scatter')

# And, here we see the clearest line all day. Go society.

# %%
# Okay, let's see if my mother was right that I would starve on the street if I majored in English ...
recent_grads.sort_values('Unemployment_rate', inplace=True)

recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate', legend=False)
recent_grads[-10:].plot.bar(x='Major', y='Unemployment_rate', legend=False)

# %%
# Huh, not what I expected. Soil Science? Now let's limit to the popular majors
pop_sort = popular.sort_values('Unemployment_rate')

pop_sort[:10].plot.bar(x='Major', y='Unemployment_rate', legend=False)
pop_sort[-10:].plot.bar(x='Major', y='Unemployment_rate', legend=False)

# %%
# Whoa, not what I expected either. I guess it's easy to find a job as a teacher or a nurse, 
# that makes sense. And I can history and philosophy majors would have a hard time finding a job.
# but Architecture has the highest unemployment rate? Maybe Econ and Poli Sci, but Computer and Info Systems?
